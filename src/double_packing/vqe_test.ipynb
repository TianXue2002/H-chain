# %%
import numpy as np
from qiskit import qpy
from qiskit.circuit.library import PauliEvolutionGate
import sys
import os

utils_path = os.path.abspath("../lib")

sys.path.append(utils_path)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
plt.figure(dpi=300)  # Default is 100
import numpy as np
import qiskit.qpy as qpy
import pickle
import json
import matplotlib.patches as mpatches
from numba import njit
from numba.typed import List
from plotting import *
from readings import *
from tile_process import *
from double_pack import *
from JW_circuit import *
from qiskit.quantum_info import SparsePauliOp
import pickle
from qiskit.quantum_info import Operator

# %%
def stilbene_packing(excitations, separation, seam_lst,
                       file_name = "./tiles/second_input_tiles.txt", if_double = False):
    bounding_width, placed_tiles_lst = first_pack(excitations, separation, seam_lst)
    if if_double:
        return bounding_width, placed_tiles_lst
    def reexport_tiles(placed_tiles):
        new_tiles = []
        for placed_tile in placed_tiles:
            cur_tile = Tile(placed_tile.w, placed_tile.h, placed_tile.dx, placed_tile.dy)
            cur_tile.pauli = placed_tile.pauli
            cur_tile.t = placed_tile.t
            new_tiles.append(cur_tile)
        return new_tiles
    
    def sort_key(tile):
        inter_module = (tile.dy - seam_lst[0]) * (tile.dy + tile.h - seam_lst[0])
        if inter_module < 0:
            inter_module = -1
        else:
            inter_module = 1
        if inter_module == -1:
            diff = min([abs(seam_lst[0] - (tile.h + tile.dy)), abs(seam_lst[0] - tile.dy)])
        else:
            diff = 0
        criteria = diff + 100 * inter_module
        criteria = (criteria, tile.dy, tile.h)
        return criteria

    ordered_placed_tiles = sorted(placed_tiles_lst, key=sort_key)
    filename = "./tiles/second_input_tiles.txt"

    new_tiles = reexport_tiles(ordered_placed_tiles)
    print(len(new_tiles), "new tile length")
    export_inter_intra(new_tiles, filename, seam_lst)
    
    print(f"second output has {len(new_tiles)} tiles")
    separation_file = "./tiles/separation.txt"
    export_separation(separation_file, separation, True)
    second_packing_c = "../lib/double_packing.exe"
    second_bounding_width, second_placed_tiles_lst = packing_with_c(new_tiles,second_packing_c)
    filename = './tiles/second_result_tiles.txt'
    bounding_width, placed_tiles_lst = read_placed_tiles(filename)
    print(f"second output has {len(placed_tiles_lst)} tiles")
    return bounding_width, placed_tiles_lst

def load_sparse_pauli_op(filename: str) -> SparsePauliOp:
    """Load SparsePauliOp from JSON file."""
    with open(filename, "r") as f:
        data = json.load(f)
    coeffs = [complex(c) for c in data["coeffs"]]
    return SparsePauliOp.from_list(list(zip(data["paulis"], coeffs)))

# %%
def process_placed_tile(placed_tiles_lst, overlap_lst):
    result_tile = []
    for placed_tile in placed_tiles_lst:
        new_tile = placed_tile.copy()
        if placed_tile in overlap_lst or overlap_lst == []:
            new_tile.overlap = True
        else:
            new_tile.overlap = False
        result_tile.append(new_tile)
    return result_tile

def draw_packing_overlap(placed_tiles_lst, bounding_width, bounding_height, seam_lst, intra_color="tomato", inter_color="cyan", new_inter_color = "olive",
                         new_intra_color = "tomato"):
    """Draws the placement of tiles with color and boundaries."""
    fig, ax = plt.subplots(figsize=(10, 6), dpi = 300)
    ax.set_aspect('auto')

    # Define the grid size and spacing between cells
    cell_size = 1  # Define the size of each grid cell (uniform size)

    # Create a colormap for each tile
    colors = plt.cm.get_cmap("tab10", len(placed_tiles_lst))
    # Draw each tile with a unique color and boundary
    for placed_tile in placed_tiles_lst:  # Only unpack two values here
        tile_x, w, h, dx, dy = placed_tile.params()
        overlap = placed_tile.overlap
        if overlap:
            rect = patches.Rectangle((tile_x + dx, dy), w, h, facecolor=new_intra_color)
        else:
            rect = patches.Rectangle((tile_x + dx, dy), w, h, facecolor=intra_color)
        for seam in seam_lst:
            if overlap and dy < seam and dy + h >= seam:
                rect = patches.Rectangle((tile_x + dx, dy), w, h, facecolor=new_inter_color)
            elif dy < seam and dy + h >= seam:
                rect = patches.Rectangle((tile_x + dx, dy), w, h, facecolor=inter_color)
        ax.add_patch(rect)

    # Set limits based on bounding box size
    ax.set_xlim(0, bounding_width)
    ax.set_ylim(0, bounding_height-1)

    # Hide the axis ticks for a cleaner look
    ax.set_xticks([])
    ax.set_yticks([])
    for seam in seam_lst:
        plt.axhline(seam - 0.5, color="purple", linewidth=3, linestyle = "--")
    plt.text(0.90, 0.03, rf"$d_c$ = {bounding_width}", ha='right', va='bottom', transform=plt.gcf().transFigure, fontsize = 30)
    plt.show()

# %%
def read_all_g(directory):
    a_idx_file = directory + "/a_idxs.json"
    i_idx_file = directory + "/i_idxs.json"
    all_g_file = directory + "/all_g.json"

    with open(a_idx_file, "rb") as f:
        a_idxs = pickle.load(f)
    
    with open(i_idx_file, "rb") as f:
        i_idxs = pickle.load(f)

    with open(all_g_file, "rb") as f:
        all_g = pickle.load(f)
    return a_idxs, i_idxs, all_g

def create_excitation(a_index, i_index, all_g, epsilon):
    excitations = []
    for [gradient, i] in all_g:
        gradient = abs(gradient)
        if gradient > epsilon:
            cur_a = a_index[i].copy()
            cur_i = i_index[i].copy()
            cur_excitation = [cur_a, cur_i]
            excitations.append(cur_excitation)
    return excitations

def swap_index(excitations, i, j):
    result = copy.deepcopy(excitations)
    for excitation in result:
        for pair in excitation:
            for k in range(2):
                idx = pair[k]
                if idx == i:
                    pair[k] = j
                elif idx == j:
                    pair[k] = i
    return result

# %%
def process_placed_tile(placed_tiles_lst, overlap_lst):
    result_tile = []
    for placed_tile in placed_tiles_lst:
        new_tile = placed_tile.copy()
        if placed_tile in overlap_lst or overlap_lst == []:
            new_tile.overlap = True
        else:
            new_tile.overlap = False
        result_tile.append(new_tile)
    return result_tile

def draw_packing_overlap(placed_tiles_lst, bounding_width, bounding_height, seam_lst, intra_color="tomato", inter_color="cyan", new_inter_color = "olive",
                         new_intra_color = "tomato"):
    """Draws the placement of tiles with color and boundaries."""
    fig, ax = plt.subplots(figsize=(10, 6), dpi = 300)
    ax.set_aspect('auto')

    # Define the grid size and spacing between cells
    cell_size = 1  # Define the size of each grid cell (uniform size)

    # Create a colormap for each tile
    colors = plt.cm.get_cmap("tab10", len(placed_tiles_lst))
    # Draw each tile with a unique color and boundary
    for placed_tile in placed_tiles_lst:  # Only unpack two values here
        tile_x, w, h, dx, dy = placed_tile.params()
        overlap = placed_tile.overlap
        if overlap:
            rect = patches.Rectangle((tile_x + dx, dy), w, h, facecolor=new_intra_color)
        else:
            rect = patches.Rectangle((tile_x + dx, dy), w, h, facecolor=intra_color)
        for seam in seam_lst:
            if overlap and dy < seam and dy + h >= seam:
                rect = patches.Rectangle((tile_x + dx, dy), w, h, facecolor=new_inter_color)
            elif dy < seam and dy + h >= seam:
                rect = patches.Rectangle((tile_x + dx, dy), w, h, facecolor=inter_color)
        ax.add_patch(rect)

    # Set limits based on bounding box size
    ax.set_xlim(0, bounding_width)
    ax.set_ylim(0, bounding_height-1)

    # Hide the axis ticks for a cleaner look
    ax.set_xticks([])
    ax.set_yticks([])
    for seam in seam_lst:
        plt.axhline(seam - 0.5, color="purple", linewidth=3, linestyle = "--")
    plt.text(0.90, 0.03, rf"$d_c$ = {bounding_width}", ha='right', va='bottom', transform=plt.gcf().transFigure, fontsize = 30)
    plt.show()

# %%
# Replace with your .qpy file path
parent_dir = "C:/Users/24835/Desktop/homework/uiuc/Covey/chem"
filename = "/stilbene/dist_0"
filename = parent_dir + filename


# filename = "polyenes/n4/for-plot/circ_dump.qpy"

# filename = "polyenes/n2/for-plot/circ_dump.qpy"

a_idxs, i_idxs, all_g = read_all_g(filename)
all_g = [[item, i] for i, item in enumerate(all_g)]
lst = [max(excitation) for excitation in a_idxs]
print(max(lst))
# Out:
# 19

# %%
n = 20
epsilon =5e-3
excitations = create_excitation(a_idxs, i_idxs, all_g, epsilon)
f_orbs = [4,2,4]
excitations = orbital_reordering(excitations, f_orbs)
print(excitations)
excitations = excitations

# print((excitations_swap))
tiles = create_circuit_tile(excitations)
# for tile in tiles:
#     print(tile.t)
# Out:
# [[array([4, 0], dtype=uint8), array([11,  3], dtype=uint8)], [array([4, 0], dtype=uint8), array([9, 7], dtype=uint8)], [array([1, 0], dtype=uint8), array([9, 2], dtype=uint8)], [array([5, 4], dtype=uint8), array([11,  6], dtype=uint8)], [array([5, 0], dtype=uint8), array([9, 7], dtype=uint8)], [array([1, 4], dtype=uint8), array([11,  3], dtype=uint8)], [array([5, 1], dtype=uint8), array([11,  2], dtype=uint8)], [array([5, 1], dtype=uint8), array([9, 6], dtype=uint8)], [array([6, 2], dtype=uint8), array([10,  1], dtype=uint8)], [array([6, 2], dtype=uint8), array([8, 5], dtype=uint8)], [array([3, 2], dtype=uint8), array([8, 1], dtype=uint8)], [array([7, 6], dtype=uint8), array([10,  5], dtype=uint8)], [array([7, 3], dtype=uint8), array([10,  0], dtype=uint8)], [array([7, 3], dtype=uint8), array([8, 4], dtype=uint8)], [array([8, 0], dtype=uint8), array([9, 2], dtype=uint8)], [array([10,  0], dtype=uint8), array([11,  2], dtype=uint8)], [array([8, 4], dtype=uint8), array([9, 6], dtype=uint8)], [array([10,  4], dtype=uint8), array([11,  6], dtype=uint8)], [array([10,  0], dtype=uint8), array([11,  9], dtype=uint8)], [array([8, 4], dtype=uint8), array([11,  9], dtype=uint8)], [array([8, 1], dtype=uint8), array([9, 3], dtype=uint8)], [array([10,  1], dtype=uint8), array([11,  3], dtype=uint8)], [array([8, 5], dtype=uint8), array([9, 7], dtype=uint8)], [array([10,  5], dtype=uint8), array([11,  7], dtype=uint8)], [array([10,  1], dtype=uint8), array([11,  9], dtype=uint8)], [array([8, 5], dtype=uint8), array([11,  9], dtype=uint8)], [array([10,  8], dtype=uint8), array([11,  2], dtype=uint8)], [array([10,  8], dtype=uint8), array([9, 6], dtype=uint8)], [array([10,  8], dtype=uint8), array([11,  3], dtype=uint8)], [array([10,  8], dtype=uint8), array([9, 7], dtype=uint8)], [array([10,  8], dtype=uint8), array([18,  9], dtype=uint8)], [array([10,  8], dtype=uint8), array([14, 11], dtype=uint8)], [array([10,  8], dtype=uint8), array([19,  9], dtype=uint8)], [array([10,  8], dtype=uint8), array([15, 11], dtype=uint8)], [array([11,  9], dtype=uint8), array([16,  8], dtype=uint8)], [array([11,  9], dtype=uint8), array([12, 10], dtype=uint8)], [array([11,  9], dtype=uint8), array([17,  8], dtype=uint8)], [array([11,  9], dtype=uint8), array([13, 10], dtype=uint8)], [array([12,  8], dtype=uint8), array([14,  9], dtype=uint8)], [array([16,  8], dtype=uint8), array([18,  9], dtype=uint8)], [array([12, 10], dtype=uint8), array([14, 11], dtype=uint8)], [array([16, 10], dtype=uint8), array([18, 11], dtype=uint8)], [array([16,  8], dtype=uint8), array([19, 15], dtype=uint8)], [array([12, 10], dtype=uint8), array([19, 15], dtype=uint8)], [array([16, 12], dtype=uint8), array([19,  9], dtype=uint8)], [array([16, 12], dtype=uint8), array([15, 11], dtype=uint8)], [array([17,  8], dtype=uint8), array([18, 14], dtype=uint8)], [array([13, 10], dtype=uint8), array([18, 14], dtype=uint8)], [array([13,  8], dtype=uint8), array([15,  9], dtype=uint8)], [array([17,  8], dtype=uint8), array([19,  9], dtype=uint8)], [array([13, 10], dtype=uint8), array([15, 11], dtype=uint8)], [array([17, 10], dtype=uint8), array([19, 11], dtype=uint8)], [array([13,  8], dtype=uint8), array([15, 14], dtype=uint8)], [array([17, 10], dtype=uint8), array([19, 18], dtype=uint8)], [array([13, 12], dtype=uint8), array([14,  9], dtype=uint8)], [array([17, 16], dtype=uint8), array([18, 11], dtype=uint8)], [array([17, 12], dtype=uint8), array([19,  9], dtype=uint8)], [array([13, 16], dtype=uint8), array([15, 11], dtype=uint8)], [array([17, 13], dtype=uint8), array([18,  9], dtype=uint8)], [array([17, 13], dtype=uint8), array([14, 11], dtype=uint8)]]

# %%
print(excitations[0])
test = [[[8, 9], [10, 11]]]
print(orbital_reordering(test, f_orbs))
# Out:
# [array([0, 4], dtype=uint8), array([ 3, 11], dtype=uint8)]
# [[[14, 15], [4, 5]]]

# %%
lst = [max(excitation[1]) for excitation in excitations]
print(max(lst))
# Out:
# 19

# %%
separation = 0
seam_lst = [10]
bounding_width, placed_tiles_lst = stilbene_packing(excitations, separation, seam_lst, if_double=False)
# Out:
# first input has 480 tiles
# Tiles successfully exported to ./tiles/inter_intra_tiles.txt
# Current Directory: c:\Users\24835\Desktop\homework\uiuc\Covey\chem\H-chain\src\double_packing\lib\tile_packing.exe
# sorted
# Tiles successfully exported to C:/Users/24835/Desktop/homework/uiuc/Covey/chem/H-chain/test_tiles.txt
# Bounding Width: 12070, Height: 0
# Total tiles: 0
# Bounding Width: 10656, Height: 19
# Total tiles: 480
# first output has 480 tiles
# 480 new tile length
# Tiles successfully exported to ./tiles/second_input_tiles.txt
# second output has 480 tiles
# Current Directory: c:\Users\24835\Desktop\homework\uiuc\Covey\chem\H-chain\src\double_packing\lib\tile_packing.exe
# sorted
# Tiles successfully exported to C:/Users/24835/Desktop/homework/uiuc/Covey/chem/H-chain/test_tiles.txt
# Bounding Width: 12070, Height: 0
# Total tiles: 0
# Bounding Width: 4288, Height: 19
# Total tiles: 480
# second output has 480 tiles

# %%
results_tile = process_placed_tile(placed_tiles_lst, [])
draw_packing_overlap(results_tile, bounding_width, n, seam_lst,new_inter_color="blue", new_intra_color="tomato", inter_color="blue")
# Out:
# C:\Users\24835\AppData\Local\Temp\ipykernel_35696\1392929189.py:22: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   colors = plt.cm.get_cmap("tab10", len(placed_tiles_lst))

# %%
import importlib
import JW_circuit
import re
import circuit_equivalency
importlib.reload(JW_circuit)
importlib.reload(circuit_equivalency)
from JW_circuit import *
from circuit_equivalency import *

i = 221
test_tiles = placed_tiles_lst
N = 20
qc, params = tile2circuit(test_tiles, N)
print(params)
print(len(qc.parameters))
# Out:
# [Parameter(t_0), Parameter(t_15), Parameter(t_18), Parameter(t_5), Parameter(t_6), Parameter(t_21), Parameter(t_24), Parameter(t_26), Parameter(t_28), Parameter(t_3), Parameter(t_17), Parameter(t_19), Parameter(t_23), Parameter(t_25), Parameter(t_35), Parameter(t_37), Parameter(t_54), Parameter(t_58), Parameter(t_44), Parameter(t_56), Parameter(t_31), Parameter(t_38), Parameter(t_33), Parameter(t_48), Parameter(t_52), Parameter(t_34), Parameter(t_36), Parameter(t_30), Parameter(t_39), Parameter(t_46), Parameter(t_32), Parameter(t_42), Parameter(t_49), Parameter(t_1), Parameter(t_2), Parameter(t_4), Parameter(t_14), Parameter(t_12), Parameter(t_10), Parameter(t_7), Parameter(t_20), Parameter(t_8), Parameter(t_9), Parameter(t_13), Parameter(t_16), Parameter(t_22), Parameter(t_11), Parameter(t_27), Parameter(t_29), Parameter(t_40), Parameter(t_50), Parameter(t_41), Parameter(t_47), Parameter(t_43), Parameter(t_51), Parameter(t_53), Parameter(t_45), Parameter(t_57), Parameter(t_59), Parameter(t_55)]
# 60

# %%
def create_custom_excitations(num_spatial_orbitals, num_particles):
    parent_dir = "C:/Users/24835/Desktop/homework/uiuc/Covey/chem"
    filename = "/stilbene/dist_0"
    filename = parent_dir + filename

    a_idxs, i_idxs, all_g = read_all_g(filename)
    all_g = [[item, i] for i, item in enumerate(all_g)]
    excitations = create_excitation(a_idxs, i_idxs, all_g, epsilon)
    f_orbs = [4,2,4]
    excitations = orbital_reordering(excitations, f_orbs)
    
    return excitations

# %%
from qiskit_nature.second_q.circuit.library import UCC
from qiskit_nature.second_q.mappers import JordanWignerMapper

# System parameters
num_spin_orbitals = 10   # total spin orbitals
num_particles = (5, 5)  # alpha and beta electrons


ucc_custom = UCC(
    num_spatial_orbitals=num_spin_orbitals,
    num_particles=num_particles,
    excitations= create_custom_excitations,  # Wrap in a function
    qubit_mapper=JordanWignerMapper()
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[277], line 9
#       5 num_spin_orbitals = 10   # total spin orbitals
#       6 num_particles = (5, 5)  # alpha and beta electrons
# ----> 9 ucc_custom = UCC(
#      10     num_spatial_orbitals=num_spin_orbitals,
#      11     num_particles=num_particles,
#      12     excitations= create_custom_excitations,  # Wrap in a function
#      13     qubit_mapper=JordanWignerMapper()
#      14 )
#
# File c:\Users\24835\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_nature\second_q\circuit\library\ansatzes\ucc.py:222, in UCC.__init__(self, num_spatial_orbitals, num_particles, excitations, qubit_mapper, alpha_spin, beta_spin, max_spin_excitation, generalized, preserve_spin, include_imaginary, reps, initial_state)
#     215 self._excitation_ops: list[SparseLabelOp] = None
#     217 # Our parent, EvolvedOperatorAnsatz, sets qregs when it knows the
#     218 # number of qubits, which it gets from the operators. Getting the
#     219 # operators here will build them if configuration already allows.
#     220 # This will allow the circuit to be fully built/valid when it's
#     221 # possible at this stage.
# --> 222 _ = self.operators
#
# File c:\Users\24835\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_nature\second_q\circuit\library\ansatzes\ucc.py:306, in UCC.operators(self)
#     298 if operators is None or operators == [None]:
#     299     # If the operators are None build them out if the ucc config checks out ok, otherwise
#     300     # they will be left as None to be built at some later time.
#     301     if self._check_ucc_configuration(raise_on_failure=False):
#     302         # The qubit operators are cached by `EvolvedOperatorAnsatz` class. We only generate
#     303         # them from the `SparseLabelOp`s produced by the generators, if they're not
#     304         # already present. This behavior also enables the adaptive usage of the `UCC` class
#     305         # by algorithms such as `AdaptVQE`.
# --> 306         excitation_ops = self.excitation_ops()
#     308         logger.debug("Converting second-quantized into qubit operators...")
#     309         # Convert operators according to saved state in mapper from the conversion of the
#     310         # main operator since these need to be compatible. If Z2 Symmetry tapering was done
#     311         # it may be that one or more excitation operators do not commute with the symmetry.
#    (...)
#     314         # the ``excitation_list`` is transformed identically to the operators, we retain
#     315         # ``None`` for non-commuting operators in order to manually remove them in unison.
#
# File c:\Users\24835\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_nature\second_q\circuit\library\ansatzes\ucc.py:417, in UCC.excitation_ops(self)
#     414 if self._excitation_ops is not None:
#     415     return self._excitation_ops
# --> 417 excitation_list = self._get_excitation_list()
#     419 self._check_excitation_list(excitation_list)
#     421 logger.debug("Converting excitations into SparseLabelOps...")
#
# File c:\Users\24835\AppData\Local\Programs\Python\Python312\Lib\site-packages\qiskit_nature\second_q\circuit\library\ansatzes\ucc.py:435, in UCC._get_excitation_list(self)
#     432 excitations = []
#     433 for gen in generators:
#     434     excitations.extend(
# --> 435         gen(  # pylint: disable=not-callable
#     436             num_spatial_orbitals=self.num_spatial_orbitals,
#     437             num_particles=self.num_particles,
#     438         )
#     439     )
#     441 return excitations
#
# Cell In[276], line 8, in create_custom_excitations(num_spatial_orbitals, num_particles)
#       6 a_idxs, i_idxs, all_g = read_all_g(filename)
#       7 all_g = [[item, i] for i, item in enumerate(all_g)]
# ----> 8 excitations = create_excitation(a_idxs, i_idxs, all_g, epsilon)
#       9 f_orbs = [4,2,4]
#      10 excitations = orbital_reordering(excitations, f_orbs)
#
# TypeError: create_excitation() takes 3 positional arguments but 4 were given

# %%
ucc_custom.decompose()
print(ucc_custom.parameters)
print(qc.parameters)
# Out:
# ParameterView([ParameterVectorElement(t[0]), ParameterVectorElement(t[1]), ParameterVectorElement(t[2]), ParameterVectorElement(t[3]), ParameterVectorElement(t[4]), ParameterVectorElement(t[5]), ParameterVectorElement(t[6]), ParameterVectorElement(t[7]), ParameterVectorElement(t[8]), ParameterVectorElement(t[9]), ParameterVectorElement(t[10]), ParameterVectorElement(t[11]), ParameterVectorElement(t[12]), ParameterVectorElement(t[13]), ParameterVectorElement(t[14]), ParameterVectorElement(t[15]), ParameterVectorElement(t[16]), ParameterVectorElement(t[17]), ParameterVectorElement(t[18]), ParameterVectorElement(t[19]), ParameterVectorElement(t[20]), ParameterVectorElement(t[21]), ParameterVectorElement(t[22]), ParameterVectorElement(t[23]), ParameterVectorElement(t[24]), ParameterVectorElement(t[25]), ParameterVectorElement(t[26]), ParameterVectorElement(t[27]), ParameterVectorElement(t[28]), ParameterVectorElement(t[29]), ParameterVectorElement(t[30]), ParameterVectorElement(t[31]), ParameterVectorElement(t[32]), ParameterVectorElement(t[33]), ParameterVectorElement(t[34]), ParameterVectorElement(t[35]), ParameterVectorElement(t[36]), ParameterVectorElement(t[37]), ParameterVectorElement(t[38]), ParameterVectorElement(t[39]), ParameterVectorElement(t[40]), ParameterVectorElement(t[41]), ParameterVectorElement(t[42]), ParameterVectorElement(t[43]), ParameterVectorElement(t[44]), ParameterVectorElement(t[45]), ParameterVectorElement(t[46]), ParameterVectorElement(t[47]), ParameterVectorElement(t[48]), ParameterVectorElement(t[49]), ParameterVectorElement(t[50]), ParameterVectorElement(t[51]), ParameterVectorElement(t[52]), ParameterVectorElement(t[53]), ParameterVectorElement(t[54]), ParameterVectorElement(t[55]), ParameterVectorElement(t[56]), ParameterVectorElement(t[57]), ParameterVectorElement(t[58]), ParameterVectorElement(t[59])])
# ParameterView([Parameter(t_0), Parameter(t_1), Parameter(t_10), Parameter(t_11), Parameter(t_12), Parameter(t_13), Parameter(t_14), Parameter(t_15), Parameter(t_16), Parameter(t_17), Parameter(t_18), Parameter(t_19), Parameter(t_2), Parameter(t_20), Parameter(t_21), Parameter(t_22), Parameter(t_23), Parameter(t_24), Parameter(t_25), Parameter(t_26), Parameter(t_27), Parameter(t_28), Parameter(t_29), Parameter(t_3), Parameter(t_30), Parameter(t_31), Parameter(t_32), Parameter(t_33), Parameter(t_34), Parameter(t_35), Parameter(t_36), Parameter(t_37), Parameter(t_38), Parameter(t_39), Parameter(t_4), Parameter(t_40), Parameter(t_41), Parameter(t_42), Parameter(t_43), Parameter(t_44), Parameter(t_45), Parameter(t_46), Parameter(t_47), Parameter(t_48), Parameter(t_49), Parameter(t_5), Parameter(t_50), Parameter(t_51), Parameter(t_52), Parameter(t_53), Parameter(t_54), Parameter(t_55), Parameter(t_56), Parameter(t_57), Parameter(t_58), Parameter(t_59), Parameter(t_6), Parameter(t_7), Parameter(t_8), Parameter(t_9)])

# %%
t_lst = np.random.rand(60)
t_lst = t_lst/100
params = qc.parameters
print(params.data)
param_values = {}
for i in range(len(t_lst)):
    p = params.data[i]
    param_values[p] = t_lst[i]

qc_bind = qc.assign_parameters(param_values)

params = ucc_custom.parameters
param_values = {}
for i in range(len(t_lst)):
    p = params.data[i]
    param_values[p] = t_lst[i]

ucc_custom_bind = ucc_custom.assign_parameters(param_values)
# print(qc_bind)
print(ucc_custom_bind)
print(qc_bind)
# Out:
# [Parameter(t_0), Parameter(t_1), Parameter(t_10), Parameter(t_11), Parameter(t_12), Parameter(t_13), Parameter(t_14), Parameter(t_15), Parameter(t_16), Parameter(t_17), Parameter(t_18), Parameter(t_19), Parameter(t_2), Parameter(t_20), Parameter(t_21), Parameter(t_22), Parameter(t_23), Parameter(t_24), Parameter(t_25), Parameter(t_26), Parameter(t_27), Parameter(t_28), Parameter(t_29), Parameter(t_3), Parameter(t_30), Parameter(t_31), Parameter(t_32), Parameter(t_33), Parameter(t_34), Parameter(t_35), Parameter(t_36), Parameter(t_37), Parameter(t_38), Parameter(t_39), Parameter(t_4), Parameter(t_40), Parameter(t_41), Parameter(t_42), Parameter(t_43), Parameter(t_44), Parameter(t_45), Parameter(t_46), Parameter(t_47), Parameter(t_48), Parameter(t_49), Parameter(t_5), Parameter(t_50), Parameter(t_51), Parameter(t_52), Parameter(t_53), Parameter(t_54), Parameter(t_55), Parameter(t_56), Parameter(t_57), Parameter(t_58), Parameter(t_59), Parameter(t_6), Parameter(t_7), Parameter(t_8), Parameter(t_9)]
#       »
#  q_0: »
#       »
#  q_1: »
#       »
#  q_2: »
#       »
#  q_3: »
#       »
#  q_4: »
#       »
#  q_5: »
#       »
#  q_6: »
#       »
#  q_7: »
#       »
#  q_8: »
#       »
#  q_9: »
#       »
# q_10: »
#       »
# q_11: »
#       »
# q_12: »
#       »
# q_13: »
#       »
# q_14: »
#       »
# q_15: »
#       »
# q_16: »
#       »
# q_17: »
#       »
# q_18: »
#       »
# q_19: »
#       »
# «      ┌───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┐
# « q_0: ┤0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_1: ┤1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_2: ┤2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_3: ┤3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_4: ┤4                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_5: ┤5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_6: ┤6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_7: ┤7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_8: ┤8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# « q_9: ┤9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ├
# «      │   EvolvedOps(0.00745,0.0078711,0.0045428,0.0032118,0.00090441,0.0016707,0.001694,0.0041833,0.0032515,0.004075,0.0086861,0.003819,0.0075937,0.0055145,0.0096711,0.009133,0.0042442,0.0099289,6.1595e-05,0.0012714,0.0070369,0.007314,0.0065903,0.00093633,0.0072522,0.0072151,0.0072085,0.0067253,0.0053011,0.0095516,0.0061964,0.0056625,0.0055053,0.0085371,0.0084813,0.0084645,0.0085772,0.0021599,0.0048984,0.0077379,0.0037413,0.0012602,0.0033206,0.0076358,0.0045339,0.005115,0.0094349,0.0053431,0.0010506,0.0096429,0.0034949,0.00053482,0.0043351,0.0087287,0.0097472,0.0079792,0.0035938,0.0042389,0.0047157,0.0037577) │
# «q_10: ┤10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_11: ┤11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_12: ┤12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_13: ┤13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_14: ┤14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_15: ┤15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_16: ┤16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_17: ┤17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_18: ┤18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      │                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   │
# «q_19: ┤19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ├
# «      └───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┘
#        ┌───┐                                                        »
#  q_0: ─┤ H ├───■────────────────────────────────────────────────────»
#        └───┘ ┌─┴─┐                                                  »
#  q_1: ───────┤ X ├──■───────────────────────────────────────────────»
#              └───┘┌─┴─┐                                             »
#  q_2: ────────────┤ X ├──■──────────────────────────────────────────»
#        ┌───┐      └───┘┌─┴─┐                                        »
#  q_3: ─┤ H ├───────────┤ X ├──■─────────────────────────────────────»
#        ├───┤           └───┘┌─┴─┐                                   »
#  q_4: ─┤ H ├────────────────┤ X ├──■────────────────────────────────»
#        └───┘                └───┘┌─┴─┐                              »
#  q_5: ───────────────────────────┤ X ├──■───────────────────────────»
#                                  └───┘┌─┴─┐                         »
#  q_6: ────────────────────────────────┤ X ├──■──────────────────────»
#                                       └───┘┌─┴─┐                    »
#  q_7: ─────────────────────────────────────┤ X ├──■─────────────────»
#                                            └───┘┌─┴─┐               »
#  q_8: ──────────────────────────────────────────┤ X ├──■────────────»
#                                                 └───┘┌─┴─┐          »
#  q_9: ───────────────────────────────────────────────┤ X ├──■───────»
#                                                      └───┘┌─┴─┐     »
# q_10: ────────────────────────────────────────────────────┤ X ├──■──»
#       ┌─────┐┌───┐                                        └───┘┌─┴─┐»
# q_11: ┤ Sdg ├┤ H ├─────────────────────────────────────────────┤ X ├»
#       ├─────┤├───┤                                             └───┘»
# q_12: ┤ Sdg ├┤ H ├──────────────────────────────────────────────────»
#       ├─────┤├───┤                                                  »
# q_13: ┤ Sdg ├┤ H ├──────────────────────────────────────────────────»
#       ├─────┤├───┤                                                  »
# q_14: ┤ Sdg ├┤ H ├──────────────────────────────────────────────────»
#       ├─────┤├───┤                                                  »
# q_15: ┤ Sdg ├┤ H ├──────────────────────────────────────────────────»
#       └┬───┬┘└───┘                                                  »
# q_16: ─┤ H ├────────────────────────────────────────────────────────»
#        ├───┤                                                        »
# q_17: ─┤ H ├────────────────────────────────────────────────────────»
#       ┌┴───┴┐┌───┐                                                  »
# q_18: ┤ Sdg ├┤ H ├──────────────────────────────────────────────────»
#       ├─────┤├───┤                                                  »
# q_19: ┤ Sdg ├┤ H ├──────────────────────────────────────────────────»
#       └─────┘└───┘                                                  »
# «                                                                          »
# « q_0: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_1: ────────────────────────────────────────────────────────────────■───»
# «                                                                    ┌─┴─┐ »
# « q_2: ──────────────────────────────────────────────────────────■───┤ X ├─»
# «                                                              ┌─┴─┐ ├───┤ »
# « q_3: ─────────────────────────────────────────────────────■──┤ X ├─┤ H ├─»
# «                                                         ┌─┴─┐├───┤┌┴───┴┐»
# « q_4: ────────────────────────────────────────────────■──┤ X ├┤ H ├┤ Sdg ├»
# «                                                    ┌─┴─┐└───┘└───┘└─────┘»
# « q_5: ───────────────────────────────────────────■──┤ X ├─────────────────»
# «                                               ┌─┴─┐└───┘                 »
# « q_6: ──────────────────────────────────────■──┤ X ├──────────────────────»
# «                                          ┌─┴─┐└───┘                      »
# « q_7: ─────────────────────────────────■──┤ X ├───────────────────────────»
# «                                     ┌─┴─┐└───┘                           »
# « q_8: ────────────────────────────■──┤ X ├────────────────────────────────»
# «                                ┌─┴─┐└───┘                                »
# « q_9: ───────────────────────■──┤ X ├─────────────────────────────────────»
# «                           ┌─┴─┐└───┘                                     »
# «q_10: ──────────────────■──┤ X ├──────────────────────────────────────────»
# «      ┌──────────────┐┌─┴─┐├───┤┌───┐┌───┐                                »
# «q_11: ┤ Rz(-0.00745) ├┤ X ├┤ H ├┤ S ├┤ H ├────────────────────────────────»
# «      └──────────────┘└───┘└───┘└───┘└───┘                                »
# «q_12: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_13: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_14: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_15: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_16: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_17: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_18: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_19: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «           ┌───┐┌───┐                                                       »
# « q_0: ──■──┤ H ├┤ H ├──■────────────────────────────────────────────────────»
# «      ┌─┴─┐└───┘└───┘┌─┴─┐                                                  »
# « q_1: ┤ X ├──────────┤ X ├──■───────────────────────────────────────────────»
# «      └───┘          └───┘┌─┴─┐                                             »
# « q_2: ────────────────────┤ X ├──■──────────────────────────────────────────»
# «      ┌───┐               └───┘┌─┴─┐                                        »
# « q_3: ┤ H ├────────────────────┤ X ├──■─────────────────────────────────────»
# «      ├───┤                    └───┘┌─┴─┐                                   »
# « q_4: ┤ H ├─────────────────────────┤ X ├──■────────────────────────────────»
# «      └───┘                         └───┘┌─┴─┐                              »
# « q_5: ───────────────────────────────────┤ X ├──■───────────────────────────»
# «                                         └───┘┌─┴─┐                         »
# « q_6: ────────────────────────────────────────┤ X ├──■──────────────────────»
# «                                              └───┘┌─┴─┐                    »
# « q_7: ─────────────────────────────────────────────┤ X ├──■─────────────────»
# «                                                   └───┘┌─┴─┐               »
# « q_8: ──────────────────────────────────────────────────┤ X ├──■────────────»
# «                                                        └───┘┌─┴─┐          »
# « q_9: ───────────────────────────────────────────────────────┤ X ├──■───────»
# «                                                             └───┘┌─┴─┐     »
# «q_10: ────────────────────────────────────────────────────────────┤ X ├──■──»
# «                                                                  └───┘┌─┴─┐»
# «q_11: ─────────────────────────────────────────────────────────────────┤ X ├»
# «                                                                       └───┘»
# «q_12: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_13: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_14: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_15: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_16: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_17: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_18: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_19: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                        »
# « q_0: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# « q_1: ───────────────────────────────────────────────────────────────■──»
# «                                                                   ┌─┴─┐»
# « q_2: ──────────────────────────────────────────────────────────■──┤ X ├»
# «                                                              ┌─┴─┐├───┤»
# « q_3: ─────────────────────────────────────────────────────■──┤ X ├┤ H ├»
# «                                                         ┌─┴─┐├───┤├───┤»
# « q_4: ────────────────────────────────────────────────■──┤ X ├┤ H ├┤ S ├»
# «                                                    ┌─┴─┐└───┘└───┘└───┘»
# « q_5: ───────────────────────────────────────────■──┤ X ├───────────────»
# «                                               ┌─┴─┐└───┘               »
# « q_6: ──────────────────────────────────────■──┤ X ├────────────────────»
# «                                          ┌─┴─┐└───┘                    »
# « q_7: ─────────────────────────────────■──┤ X ├─────────────────────────»
# «                                     ┌─┴─┐└───┘                         »
# « q_8: ────────────────────────────■──┤ X ├──────────────────────────────»
# «                                ┌─┴─┐└───┘                              »
# « q_9: ───────────────────────■──┤ X ├───────────────────────────────────»
# «                           ┌─┴─┐└───┘                                   »
# «q_10: ──────────────────■──┤ X ├────────────────────────────────────────»
# «      ┌──────────────┐┌─┴─┐├───┤┌───┐                                   »
# «q_11: ┤ Rz(-0.00745) ├┤ X ├┤ H ├┤ H ├───────────────────────────────────»
# «      └──────────────┘└───┘└───┘└───┘                                   »
# «q_12: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_13: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_14: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_15: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_16: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_17: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_18: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «q_19: ──────────────────────────────────────────────────────────────────»
# «                                                                        »
# «             ┌───┐┌─────┐┌───┐                                             »
# « q_0: ───■───┤ H ├┤ Sdg ├┤ H ├──■──────────────────────────────────────────»
# «       ┌─┴─┐ └───┘└─────┘└───┘┌─┴─┐                                        »
# « q_1: ─┤ X ├──────────────────┤ X ├──■─────────────────────────────────────»
# «       └───┘                  └───┘┌─┴─┐                                   »
# « q_2: ─────────────────────────────┤ X ├──■────────────────────────────────»
# «      ┌─────┐┌───┐                 └───┘┌─┴─┐                              »
# « q_3: ┤ Sdg ├┤ H ├──────────────────────┤ X ├──■───────────────────────────»
# «      ├─────┤├───┤                      └───┘┌─┴─┐                         »
# « q_4: ┤ Sdg ├┤ H ├───────────────────────────┤ X ├──■──────────────────────»
# «      └─────┘└───┘                           └───┘┌─┴─┐                    »
# « q_5: ────────────────────────────────────────────┤ X ├──■─────────────────»
# «                                                  └───┘┌─┴─┐               »
# « q_6: ─────────────────────────────────────────────────┤ X ├──■────────────»
# «                                                       └───┘┌─┴─┐          »
# « q_7: ──────────────────────────────────────────────────────┤ X ├──■───────»
# «                                                            └───┘┌─┴─┐     »
# « q_8: ───────────────────────────────────────────────────────────┤ X ├──■──»
# «                                                                 └───┘┌─┴─┐»
# « q_9: ────────────────────────────────────────────────────────────────┤ X ├»
# «                                                                      └───┘»
# «q_10: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_11: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_12: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_13: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_14: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_15: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_16: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_17: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_18: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_19: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                              »
# « q_0: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_1: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# « q_2: ─────────────────────────────────────────────────────────────────────■──»
# «                                                                         ┌─┴─┐»
# « q_3: ────────────────────────────────────────────────────────────────■──┤ X ├»
# «                                                                    ┌─┴─┐├───┤»
# « q_4: ───────────────────────────────────────────────────────────■──┤ X ├┤ H ├»
# «                                                               ┌─┴─┐└───┘└───┘»
# « q_5: ──────────────────────────────────────────────────────■──┤ X ├──────────»
# «                                                          ┌─┴─┐└───┘          »
# « q_6: ─────────────────────────────────────────────────■──┤ X ├───────────────»
# «                                                     ┌─┴─┐└───┘               »
# « q_7: ────────────────────────────────────────────■──┤ X ├────────────────────»
# «                                                ┌─┴─┐└───┘                    »
# « q_8: ──────────────────────────────────────■───┤ X ├─────────────────────────»
# «                                          ┌─┴─┐ └───┘                         »
# « q_9: ──■─────────────────────────────■───┤ X ├───────────────────────────────»
# «      ┌─┴─┐                         ┌─┴─┐ └───┘                               »
# «q_10: ┤ X ├──■───────────────────■──┤ X ├─────────────────────────────────────»
# «      └───┘┌─┴─┐┌─────────────┐┌─┴─┐├───┤┌─────┐┌───┐                         »
# «q_11: ─────┤ X ├┤ Rz(0.00745) ├┤ X ├┤ H ├┤ Sdg ├┤ H ├─────────────────────────»
# «           └───┘└─────────────┘└───┘└───┘└─────┘└───┘                         »
# «q_12: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_13: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_14: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_15: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_16: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_17: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_18: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «q_19: ────────────────────────────────────────────────────────────────────────»
# «                                                                              »
# «                   ┌───┐ ┌───┐┌───┐                                        »
# « q_0: ────────■────┤ H ├─┤ S ├┤ H ├──■─────────────────────────────────────»
# «            ┌─┴─┐  └───┘ └───┘└───┘┌─┴─┐                                   »
# « q_1: ──■───┤ X ├──────────────────┤ X ├──■────────────────────────────────»
# «      ┌─┴─┐ └───┘                  └───┘┌─┴─┐                              »
# « q_2: ┤ X ├─────────────────────────────┤ X ├──■───────────────────────────»
# «      ├───┤ ┌───┐ ┌─────┐┌───┐          └───┘┌─┴─┐                         »
# « q_3: ┤ H ├─┤ S ├─┤ Sdg ├┤ H ├───────────────┤ X ├──■──────────────────────»
# «      ├───┤┌┴───┴┐└┬───┬┘└───┘               └───┘┌─┴─┐                    »
# « q_4: ┤ S ├┤ Sdg ├─┤ H ├──────────────────────────┤ X ├──■─────────────────»
# «      └───┘└─────┘ └───┘                          └───┘┌─┴─┐               »
# « q_5: ─────────────────────────────────────────────────┤ X ├──■────────────»
# «                                                       └───┘┌─┴─┐          »
# « q_6: ──────────────────────────────────────────────────────┤ X ├──■───────»
# «                                                            └───┘┌─┴─┐     »
# « q_7: ───────────────────────────────────────────────────────────┤ X ├──■──»
# «                                                                 └───┘┌─┴─┐»
# « q_8: ────────────────────────────────────────────────────────────────┤ X ├»
# «                                                                      └───┘»
# « q_9: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_10: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_11: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_12: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_13: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_14: ─────────────────────────────────────────────────────────────────────»
# ...
# «                                                                           »
# « q_5: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# « q_6: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# « q_7: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# « q_8: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# « q_9: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «q_10: ─────────────────────────────────────────────────────────────────────»
# «                            ┌───┐┌───┐┌─────┐┌───┐                         »
# «q_11: ───────────────────■──┤ H ├┤ S ├┤ Sdg ├┤ H ├──■──────────────────────»
# «                       ┌─┴─┐└───┘└───┘└─────┘└───┘┌─┴─┐                    »
# «q_12: ──────────────■──┤ X ├──────────────────────┤ X ├──■─────────────────»
# «                  ┌─┴─┐└───┘                      └───┘┌─┴─┐               »
# «q_13: ─────────■──┤ X ├────────────────────────────────┤ X ├──■────────────»
# «             ┌─┴─┐└───┘                                └───┘┌─┴─┐          »
# «q_14: ───■───┤ X ├──────────────────────────────────────────┤ X ├──■───────»
# «       ┌─┴─┐ └───┘                                          └───┘┌─┴─┐     »
# «q_15: ─┤ X ├─────────────────────────────────────────────────────┤ X ├──■──»
# «       ├───┤ ┌───┐                                               └───┘┌─┴─┐»
# «q_16: ─┤ H ├─┤ H ├────────────────────────────────────────────────────┤ X ├»
# «      ┌┴───┴┐├───┤                                                    └───┘»
# «q_17: ┤ Sdg ├┤ H ├─────────────────────────────────────────────────────────»
# «      └┬───┬┘└───┘                                                         »
# «q_18: ─┤ H ├───────────────────────────────────────────────────────────────»
# «       └───┘                                                               »
# «q_19: ─────────────────────────────────────────────────────────────────────»
# «                                                                           »
# «                                                                          »
# « q_0: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_1: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_2: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_3: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_4: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_5: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_6: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_7: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_8: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_9: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_10: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_11: ─────────────────────────────────────────────────────────────────■──»
# «                                                                     ┌─┴─┐»
# «q_12: ────────────────────────────────────────────────────────────■──┤ X ├»
# «                                                                ┌─┴─┐└───┘»
# «q_13: ──────────────────────────────────────────────────────■───┤ X ├─────»
# «                                                          ┌─┴─┐ └───┘     »
# «q_14: ───────────────────────────────────────────────■────┤ X ├───────────»
# «                                                   ┌─┴─┐  └───┘           »
# «q_15: ─────────────────────────────────────────■───┤ X ├──────────────────»
# «                                             ┌─┴─┐ ├───┤ ┌─────┐┌───┐     »
# «q_16: ──■─────────────────────────────────■──┤ X ├─┤ H ├─┤ Sdg ├┤ H ├─────»
# «      ┌─┴─┐                             ┌─┴─┐├───┤ ├───┤ └┬───┬┘└───┘     »
# «q_17: ┤ X ├──■───────────────────────■──┤ X ├┤ H ├─┤ S ├──┤ H ├───────────»
# «      └───┘┌─┴─┐┌─────────────────┐┌─┴─┐├───┤├───┤┌┴───┴┐ ├───┤           »
# «q_18: ─────┤ X ├┤ Rz(-0.00053482) ├┤ X ├┤ H ├┤ S ├┤ Sdg ├─┤ H ├───────────»
# «           └───┘└─────────────────┘└───┘└───┘└───┘└─────┘ └───┘           »
# «q_19: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «                                                               »
# « q_0: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_1: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_2: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_3: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_4: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_5: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_6: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_7: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_8: ─────────────────────────────────────────────────────────»
# «                                                               »
# « q_9: ─────────────────────────────────────────────────────────»
# «                                                               »
# «q_10: ─────────────────────────────────────────────────────────»
# «      ┌───┐┌───┐┌─────┐┌───┐                                   »
# «q_11: ┤ H ├┤ S ├┤ Sdg ├┤ H ├──■────────────────────────────────»
# «      └───┘└───┘└─────┘└───┘┌─┴─┐                              »
# «q_12: ──────────────────────┤ X ├──■───────────────────────────»
# «                            └───┘┌─┴─┐                         »
# «q_13: ───────────────────────────┤ X ├──■──────────────────────»
# «                                 └───┘┌─┴─┐                    »
# «q_14: ────────────────────────────────┤ X ├──■─────────────────»
# «                                      └───┘┌─┴─┐               »
# «q_15: ─────────────────────────────────────┤ X ├──■────────────»
# «                                           └───┘┌─┴─┐          »
# «q_16: ──────────────────────────────────────────┤ X ├──■───────»
# «                                                └───┘┌─┴─┐     »
# «q_17: ───────────────────────────────────────────────┤ X ├──■──»
# «                                                     └───┘┌─┴─┐»
# «q_18: ────────────────────────────────────────────────────┤ X ├»
# «                                                          └───┘»
# «q_19: ─────────────────────────────────────────────────────────»
# «                                                               »
# «                                                                            »
# « q_0: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_1: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_2: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_3: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_4: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_5: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_6: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_7: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_8: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# « q_9: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «q_10: ──────────────────────────────────────────────────────────────────────»
# «                                                             ┌───┐┌───┐┌───┐»
# «q_11: ────────────────────────────────────────────────────■──┤ H ├┤ S ├┤ H ├»
# «                                                        ┌─┴─┐└───┘└───┘└───┘»
# «q_12: ──────────────────────────────────────────────■───┤ X ├───────────────»
# «                                                  ┌─┴─┐ └───┘               »
# «q_13: ────────────────────────────────────────■───┤ X ├─────────────────────»
# «                                            ┌─┴─┐ └───┘                     »
# «q_14: ───────────────────────────────────■──┤ X ├───────────────────────────»
# «                                       ┌─┴─┐└───┘                           »
# «q_15: ──────────────────────────────■──┤ X ├────────────────────────────────»
# «                                  ┌─┴─┐├───┤┌───┐┌─────┐┌───┐               »
# «q_16: ─────────────────────────■──┤ X ├┤ H ├┤ S ├┤ Sdg ├┤ H ├───────────────»
# «                             ┌─┴─┐├───┤├───┤└───┘└─────┘└───┘               »
# «q_17: ────────────────────■──┤ X ├┤ H ├┤ H ├────────────────────────────────»
# «      ┌────────────────┐┌─┴─┐├───┤├───┤├───┤                                »
# «q_18: ┤ Rz(0.00053482) ├┤ X ├┤ H ├┤ S ├┤ H ├────────────────────────────────»
# «      └────────────────┘└───┘└───┘└───┘└───┘                                »
# «q_19: ──────────────────────────────────────────────────────────────────────»
# «                                                                            »
# «                                                                          »
# « q_0: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_1: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_2: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_3: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_4: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_5: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_6: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_7: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_8: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# « q_9: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_10: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «q_11: ──■─────────────────────────────────────────────────────────────────»
# «      ┌─┴─┐                                                               »
# «q_12: ┤ X ├──■────────────────────────────────────────────────────────────»
# «      └───┘┌─┴─┐                                                          »
# «q_13: ─────┤ X ├──■───────────────────────────────────────────────────────»
# «           └───┘┌─┴─┐                                                     »
# «q_14: ──────────┤ X ├──■──────────────────────────────────────────────────»
# «                └───┘┌─┴─┐                                                »
# «q_15: ───────────────┤ X ├──■──────────────────────────────────────────■──»
# «                     └───┘┌─┴─┐                                      ┌─┴─┐»
# «q_16: ────────────────────┤ X ├──■────────────────────────────────■──┤ X ├»
# «                          └───┘┌─┴─┐                            ┌─┴─┐├───┤»
# «q_17: ─────────────────────────┤ X ├──■──────────────────────■──┤ X ├┤ H ├»
# «                               └───┘┌─┴─┐┌────────────────┐┌─┴─┐├───┤└───┘»
# «q_18: ──────────────────────────────┤ X ├┤ Rz(0.00053482) ├┤ X ├┤ H ├─────»
# «                                    └───┘└────────────────┘└───┘└───┘     »
# «q_19: ────────────────────────────────────────────────────────────────────»
# «                                                                          »
# «
# « q_0: ─────────────────────────
# «
# « q_1: ─────────────────────────
# «
# « q_2: ─────────────────────────
# «
# « q_3: ─────────────────────────
# «
# « q_4: ─────────────────────────
# «
# « q_5: ─────────────────────────
# «
# « q_6: ─────────────────────────
# «
# « q_7: ─────────────────────────
# «
# « q_8: ─────────────────────────
# «
# « q_9: ─────────────────────────
# «
# «q_10: ─────────────────────────
# «                          ┌───┐
# «q_11: ─────────────────■──┤ H ├
# «                     ┌─┴─┐└───┘
# «q_12: ────────────■──┤ X ├─────
# «                ┌─┴─┐└───┘
# «q_13: ───────■──┤ X ├──────────
# «           ┌─┴─┐└───┘
# «q_14: ──■──┤ X ├───────────────
# «      ┌─┴─┐└───┘
# «q_15: ┤ X ├────────────────────
# «      ├───┤┌───┐
# «q_16: ┤ H ├┤ S ├───────────────
# «      └───┘└───┘
# «q_17: ─────────────────────────
# «
# «q_18: ─────────────────────────
# «
# «q_19: ─────────────────────────
# «

# %%
import numpy as np
from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector

def circuits_equivalent(circ1, circ2, num_tests=1, tol=1e-6):
    n_qubits = circ1.num_qubits
    # Random normalized state
    psi0 = np.random.randn(2**n_qubits) + 1j*np.random.randn(2**n_qubits)
    psi0 /= np.linalg.norm(psi0)
    sv0 = Statevector(psi0)

    # Evolve with both circuits
    print("start eovlove")
    out1 = sv0.evolve(circ1)
    print("hi")
    out2 = sv0.evolve(circ2)

    return psi0, out1, out2

psi0, out1, out2 = circuits_equivalent(qc_bind, ucc_custom_bind)
# Out:
# start eovlove
# hi

# %%
print(np.linalg.norm(out1.data - out2.data))
print(np.linalg.norm(out2.data - psi0))
# Out:
# 0.07241568659840487
# 0.016922287961884153

# %%
importlib.reload(JW_circuit)
from JW_circuit import *
print(double_index(1,4,3,11,"YXYY") * -1)
# Out:
# 1
# 1.0
